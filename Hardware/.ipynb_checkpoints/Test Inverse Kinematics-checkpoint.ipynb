# %% [markdown]
# We start by importing all our libraries

# %%
import ikpy.chain
import ikpy.utils.plot as plot_utils

import numpy as np
import math

import serial

# %% [markdown]
# Now, we can import our robot arm model from the URDF file. The first link is the link between the desk and the base, which doesn't move, so we set it to inactive

# %%
my_chain = ikpy.chain.Chain.from_urdf_file("test_arm_urdf.urdf", active_links_mask=[False, True, True, True, True, True, True])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 my_chain = ikpy.chain.Chain.from_urdf_file("test_arm_urdf.urdf", active_links_mask=[False, True, True, True, True, True, True])
#
# File c:\datacloak\Huy\ACM\Fall-2025-ACM-Project-Hub\venv\lib\site-packages\ikpy\chain.py:324, in Chain.from_urdf_file(cls, urdf_file, base_elements, last_link_vector, base_element_type, active_links_mask, name, symbolic)
#     321 if base_elements is None:
#     322     base_elements = ["base_link"]
# --> 324 links = URDF.get_urdf_parameters(urdf_file, base_elements=base_elements, last_link_vector=last_link_vector, base_element_type=base_element_type, symbolic=symbolic)
#     325 # Add an origin link at the beginning
#     326 chain = cls([link_lib.OriginLink()] + links, active_links_mask=active_links_mask, name=name, urdf_metadata=urdf_metadata)
#
# File c:\datacloak\Huy\ACM\Fall-2025-ACM-Project-Hub\venv\lib\site-packages\ikpy\urdf\URDF.py:184, in get_urdf_parameters(urdf_file, base_elements, last_link_vector, base_element_type, symbolic)
#     164 def get_urdf_parameters(urdf_file, base_elements=None, last_link_vector=None, base_element_type="link", symbolic=True):
#     165     """
#     166     Returns translated parameters from the given URDF file.
#     167     Parse the URDF joints into IKPY links, throw away the URDF links.
#    (...)
#     182     list[ikpy.link.URDFLink]
#     183     """
# --> 184     tree = ET.parse(urdf_file)
#     185     root = tree.getroot()
#     186     base_elements = list(base_elements)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\xml\etree\ElementTree.py:1222, in parse(source, parser)
#    1213 """Parse XML document into element tree.
#    1214
#    1215 *source* is a filename or file object containing XML data,
#    (...)
#    1219
#    1220 """
#    1221 tree = ElementTree()
# -> 1222 tree.parse(source, parser)
#    1223 return tree
#
# File ~\AppData\Local\Programs\Python\Python310\lib\xml\etree\ElementTree.py:569, in ElementTree.parse(self, source, parser)
#     567 close_source = False
#     568 if not hasattr(source, "read"):
# --> 569     source = open(source, "rb")
#     570     close_source = True
#     571 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test_arm_urdf.urdf'

# %% [markdown]
# And set the target position and orientation of the arm

# %%
target_position = [0, 0.2, 0.1]

target_orientation = [-1, 0, 0]

# %% [markdown]
# It's now just one call to work out the inverse kinematics for that position. Again, the first angle is of the inactive joint between the desk and the base so is always 0

# %%
ik = my_chain.inverse_kinematics(target_position, target_orientation, orientation_mode="Y")
print("The angles of each joints are: ", list(map(lambda r: math.degrees(r), ik.tolist())))
# Out:
# The angles of each joints are:  [0.0, 0.0001529343452297761, -33.739782094928344, -110.00789666511804, -4.929192608995393e-05, 27.50197416627951, 89.99980512365119]

# %% [markdown]
# We can see the actual position our robot will move to. This may be different to target_position as the arm may not be physically able to reach that position

# %%
computed_position = my_chain.forward_kinematics(ik)
print("Computed position:", [f"{val:.2f}" for val in computed_position[:3, 3]])
# Out:
# Computed position: ['0.00', '0.25', '0.10']

# %% [markdown]
# Now let's visualize what our arm looks

# %%
# %matplotlib qt
import matplotlib.pyplot as plt
fig, ax = plot_utils.init_3d_figure()
fig.set_figheight(18)  
fig.set_figwidth(26)  
my_chain.plot(ik, ax, target=target_position)
plt.xlim(-0.5, 0.5)
plt.ylim(-0.5, 0.5)
ax.set_zlim(0, 0.6)
plt.ion()

# %% [markdown]
# Now we'll wrap up some of these calls into a couple of functions. Calling move(x,y,z) will move us to the new coordinates and update the plot.
#
# It's worth noting here that when we call inverse_kinematics, we pass in the old position (joint angles) as initial_position so IKPY find the nearest solution to our current position.

# %%
def doIK():
    global ik
    old_position = ik.copy()
    ik = my_chain.inverse_kinematics(target_position, target_orientation, orientation_mode="Y", initial_position=old_position)

def updatePlot():
    ax.cla()
    my_chain.plot(ik, ax, target=target_position)
    ax.set_xlim(-0.5, 0.5)
    ax.set_ylim(-0.5, 0.5)
    ax.set_zlim(0, 0.6)
    fig.canvas.draw_idle()
    
def move(x,y,z):
    global target_position
    target_position = [x,y,z]
    doIK()
    updatePlot()

    #sendCommand(ik[1].item(),ik[2].item(),ik[3].item(),ik[4].item(),ik[5].item(),ik[6].item(),1)

# %% [markdown]
# We should now be able to move our visualized arm with a call to move(x,y,z)

# %%
move(0, 0.1, 0.2)
